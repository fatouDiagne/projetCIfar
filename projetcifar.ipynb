# %% [markdown]
# <a href="https://colab.research.google.com/github/fatouDiagne/projetCIfar/blob/main/projetcifar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importation des donnés#
import tensorflow as tf
tf.keras.datasets.cifar100.load_data(label_mode="fine")
# Out:
# ...
# 169001437/169001437 [==============================] - 12s 0us/step
# ((array([[[[255, 255, 255],
#            [255, 255, 255],
#            [255, 255, 255],
#            ...,
#            [195, 205, 193],
#            [212, 224, 204],
#            [182, 194, 167]],
#
#           [[255, 255, 255],
#            [254, 254, 254],
#            [254, 254, 254],
#            ...,
#            [170, 176, 150],
#            [161, 168, 130],
#            [146, 154, 113]],
#
#           [[255, 255, 255],
#            [254, 254, 254],
#            [255, 255, 255],
#            ...,
#            [189, 199, 169],
#            [166, 178, 130],
#            [121, 133,  87]],
#
#           ...,
#
#           [[148, 185,  79],
#            [142, 182,  57],
#            [140, 179,  60],
#            ...,
#            [ 30,  17,   1],
#            [ 65,  62,  15],
#            [ 76,  77,  20]],
#
#           [[122, 157,  66],
#            [120, 155,  58],
#            [126, 160,  71],
# ...

# %%
import keras
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()
#affichage des donné sous forme tableau#
assert x_train.shape == (50000, 32, 32, 3)
assert x_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (50000, 1)
assert y_test.shape == (10000, 1)

# %%
print(x_train.shape)
print(y_test.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 1)
# (50000, 1)
# (10000, 32, 32, 3)

# %%
#visualisation des données sous format images#
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (9,9) # Make the figures a bit bigger
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(x_train[i+9], cmap='gray', interpolation='none')
    plt.title("Class {}".format(y_train[i+9]))

# %%
type(x_train)
x_train.shape 
len(x_train)
print(" Type of data structure for the images : {}".format(type(x_train)))
print(" Type of data structure for the labels : {}".format(type(y_train)))

print(" Shape of the train images encoded as numpy arrays :  {}".format(x_train.shape))
print(" Length of the associated labels : {}".format(len(y_train)))

print(" Shape of the test images encoded as numpy arrays :  {}".format(x_test.shape))
print(" Length of the associated labels : {}".format(len(y_test)))

print(" Shape of an image : {}".format(x_train[0].shape))
print(" Example image : \n {}".format(x_train[0]))
# Out:
#  Type of data structure for the images : <class 'numpy.ndarray'>
#  Type of data structure for the labels : <class 'numpy.ndarray'>
#  Shape of the train images encoded as numpy arrays :  (10000, 1)
#  Length of the associated labels : 50000
#  Shape of the test images encoded as numpy arrays :  (10000, 32, 32, 3)
#  Length of the associated labels : 10000
#  Shape of an image : (1,)
#  Example image :
#  [0.19215687]

# %%
train_counts=[]
test_counts=[]
for i in range(0,10):
  train_counts.append(len([k for k in y_train if k ==i]))
  test_counts.append(len([k for k in y_test if k ==i ]))

  
plt.rcParams['figure.figsize'] = (16,8) # Make the figures a bit bigger
fig,(ax1,ax2,) = plt.subplots(1,2)

x = range(0,10)
ax1.bar(x,train_counts)
ax1.set_title("count of apparition for each digit in the training set ")


ax2.bar(x,test_counts)
ax2.set_title("count of apparition for each digit in the test set ")



plt.show()

# %%
x_train = x_train.reshape((10000,32*32, 3))
x_train = x_train.astype('float32') / 255 

test_images = test_images.reshape((10000,1))
test_images = test_images.astype('float32')/255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-dc1b8003ccf9> in <module>
# ----> 1 x_train = x_train.reshape((10000,32*32, 3))
#       2 x_train = x_train.astype('float32') / 255
#       3
#       4 test_images = test_images.reshape((10000,1))
#       5 test_images = test_images.astype('float32')/255
#
# ValueError: cannot reshape array of size 10000 into shape (10000,1024,3)
